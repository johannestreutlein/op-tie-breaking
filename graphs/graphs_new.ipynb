# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pymongo
import os, sys, yaml
import numpy as np
from scipy import stats

root_dir = "/home/marilena/PycharmProjects/3rdyearproject/pymarl-dev/src"

# %%
def get_default_config():
    with open(root_dir + "/config/default.yaml", 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)

# %%
def get_mongo_db_client(db_url, db_name):   
    maxSevSelDelay = 10000  # Assume 10s maximum server selection delay
    
    client = pymongo.MongoClient(db_url, ssl=True, serverSelectionTimeoutMS=maxSevSelDelay)
    
    print(client)
    
    return client, client[db_name]

# %%
config = get_default_config()

mongo_client, mongo_db = get_mongo_db_client(config["db_url"], config["db_name"])
# Out:
# MongoClient(host=['gandalf.cs.ox.ac.uk:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, serverselectiontimeoutms=10000)

# %%
possible_experiments = ["coma_", "coma_vdn_", "centralV_", "coma_qmix_", "coma_nb_", \
                        "coma_qmix_ns_", "coma_vdn_nb_", "coma_vdn_vb_", "coma_fql_", \
                       "coma_vdn_vmb_", "centralV_vdn_"]
lambdas = ["03", "05", "07", "09"] #"01", "03", "05", "07", "08", "09"

game_step_counts = {
    "sh": 1500000,
    "sc_2s3z": 2000000,
    "sc_3m": 2000000,
    "sc_2m_vs_1z": 2000000,
    "sc_25m": 10000000,
    "sc_8m": 2000000,
    "sc_smb": 2000000,
    "sc_bvb": 2000000,
    "sc_3s5z": 2000000
}

game_titles = {
    "sh": "Stag Hunt",
    "sc_2s3z": "Starcraft, map 2s_3z",
    "sc_3m": "Starcraft, map 3m",
    "sc_2m_vs_1z": "Starcraft, map 2m_vs_1z",
    "sc_25m": "Starcraft, map 25m",
    "sc_8m": "Starcraft, map 8m",
    "sc_smb": "Starcraft, so many banelings",
    "sc_bvb": "Starcraft, bane vs bane",
    "sc_3s5z": "Starcraft, map 3s5z"
}

axes_labels = {
    "test_return_mean": "Test Return Mean",
    "test_battle_won_mean": "Test Battle Won Mean %"
}

DATAPOINTS_COUNT = 5001

all_colors = ["red", "blue", "green", "orange", "purple", "brown", "pink", "yellow"]
exp_color_map = {
    "coma_vdn_": "blue",
    "coma_": "red",
    "centralV_": "green",
    "coma_qmix_": "orange",
    "coma_nb_": "brown",
    "coma_qmix_ns_": "pink",
    "coma_vdn_nb_": "orange",
    "coma_vdn_vb_": "purple",
    "coma_fql_": "magenta",
    "coma_vdn_vmb_": "magenta",
    "centralV_vdn_": "magenta"
}

# %%
def get_exp_ids_from_db(config_db):    
    results = []
    
    query = mongo_db["runs"].find(config_db)
    results.extend([q["config"] for q in query])
    
    eliminate_known_bad_exp_names()
    print(results)
    return results

# %%
get_exp_ids_from_db(get_config_for_db(None,None, None))
# Out:
# [{'critic_baseline_fn': 'coma', 'critic_train_mode': 'seq', 'save_model': False, 'lr': 0.0005, 'mixer_lr': 0.0005, 'save_replay': False, 'learner': 'coma_learner', 'optim_eps': 1e-05, 'optim_alpha': 0.99, 'env_args': {'p_hare_rest': 0.0, 'truncate_episodes': True, 'n_agents': 4, 'world_shape': [6, 6], 'print_caught_prey': False, 'p_stags_rest': 0.0, 'intersection_unknown': False, 'observe_one_hot': False, 'agent_obs': [2, 2], 'state_last_action': False, 'reward_stag': 10, 'observe_ids': False, 'intersection_global_view': False, 'reward_collision': 0.0, 'capture_terminal': True, 'reward_hare': 5, 'n_hare': 1, 'toroidal': False, 'observe_walls': False, 'mountain_slope': 0.0, 'capture_conditions': [0, 1], 'episode_limit': 100, 'reward_time': -0.1, 'n_stags': 1}, 'action_selector': 'multinomial', 'mixing_embed_dim': 32, 't_max': 1510000, 'load_step': 0, 'use_cuda': True, 'batch_size_run': 8, 'critic_lr': 0.0005, 'critic_train_reps': 1, 'critic_q_fn': 'coma', 'epsilon_finish': 0.01, 'epsilon_anneal_time': 100000, 'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl', 'rnn_hidden_dim': 64, 'q_nstep': 0, 'obs_last_action': True, 'name': 'exp_marilena_coma_sh_1', 'epsilon_start': 0.5, 'obs_agent_id': True, 'mac': 'basic_mac', 'test_greedy': True, 'local_results_path': 'results', 'test_nepisode': 20, 'checkpoint_path': '', 'gamma': 0.99, 'env': 'stag_hunt', 'evaluate': False, 'critic_fact': None, 'seed': 722132159, 'repeat_id': 1, 'no-mongo': False, 'use_tensorboard': True, 'label': 'exp_marilena_coma_sh_1', 'grad_norm_clip': 10, 'mask_before_softmax': False, 'test_interval': 2000, 'buffer_size': 8, 'db_name': 'pymarl', 'save_model_interval': 2000000, 'learner_log_interval': 2000, 'agent': 'rnn', 'runner_log_interval': 2000, 'target_update_interval': 200, 'log_interval': 2000, 'td_lambda': 0.8, 'runner': 'parallel', 'batch_size': 8, 'buffer_cpu_only': True, 'agent_output_type': 'pi_logits'}, {'db_name': 'pymarl', 'name': 'exp_marilena_coma_sh_2', 'save_replay': False, 'repeat_id': 1, 'epsilon_anneal_time': 100000, 'test_nepisode': 20, 'save_model_interval': 2000000, 'action_selector': 'multinomial', 'evaluate': False, 'seed': 352253311, 'load_step': 0, 'test_greedy': True, 'q_nstep': 0, 'epsilon_finish': 0.01, 'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl', 'rnn_hidden_dim': 64, 'learner': 'coma_learner', 'buffer_cpu_only': True, 'label': 'exp_marilena_coma_sh_2', 'local_results_path': 'results', 'save_model': False, 'env': 'stag_hunt', 'obs_last_action': True, 'optim_alpha': 0.99, 'obs_agent_id': True, 'td_lambda': 0.8, 'agent_output_type': 'pi_logits', 'target_update_interval': 200, 'mixer_lr': 0.0005, 'critic_baseline_fn': 'coma', 'batch_size': 8, 'critic_train_reps': 1, 't_max': 1510000, 'mask_before_softmax': False, 'no-mongo': False, 'checkpoint_path': '', 'critic_fact': None, 'gamma': 0.99, 'test_interval': 2000, 'runner_log_interval': 2000, 'mac': 'basic_mac', 'critic_lr': 0.0005, 'critic_train_mode': 'seq', 'log_interval': 2000, 'optim_eps': 1e-05, 'mixing_embed_dim': 32, 'agent': 'rnn', 'lr': 0.0005, 'buffer_size': 8, 'env_args': {'reward_collision': 0.0, 'capture_conditions': [0, 1], 'n_agents': 4, 'n_hare': 1, 'intersection_global_view': False, 'state_last_action': False, 'observe_ids': False, 'agent_obs': [2, 2], 'world_shape': [6, 6], 'capture_terminal': True, 'reward_hare': 5, 'reward_time': -0.1, 'truncate_episodes': True, 'p_stags_rest': 0.0, 'n_stags': 1, 'reward_stag': 10, 'observe_walls': False, 'mountain_slope': 0.0, 'observe_one_hot': False, 'toroidal': False, 'print_caught_prey': False, 'p_hare_rest': 0.0, 'episode_limit': 100, 'intersection_unknown': False}, 'runner': 'parallel', 'batch_size_run': 8, 'critic_q_fn': 'coma', 'grad_norm_clip': 10, 'learner_log_interval': 2000, 'use_cuda': True, 'epsilon_start': 0.5, 'use_tensorboard': True}, {'local_results_path': 'results', 'agent': 'rnn', 'load_step': 0, 'runner_log ...
# [{'critic_baseline_fn': 'coma',
#   'critic_train_mode': 'seq',
#   'save_model': False,
#   'lr': 0.0005,
#   'mixer_lr': 0.0005,
#   'save_replay': False,
#   'learner': 'coma_learner',
#   'optim_eps': 1e-05,
#   'optim_alpha': 0.99,
#   'env_args': {'p_hare_rest': 0.0,
#    'truncate_episodes': True,
#    'n_agents': 4,
#    'world_shape': [6, 6],
#    'print_caught_prey': False,
#    'p_stags_rest': 0.0,
#    'intersection_unknown': False,
#    'observe_one_hot': False,
#    'agent_obs': [2, 2],
#    'state_last_action': False,
#    'reward_stag': 10,
#    'observe_ids': False,
#    'intersection_global_view': False,
#    'reward_collision': 0.0,
#    'capture_terminal': True,
#    'reward_hare': 5,
#    'n_hare': 1,
#    'toroidal': False,
#    'observe_walls': False,
#    'mountain_slope': 0.0,
#    'capture_conditions': [0, 1],
#    'episode_limit': 100,
#    'reward_time': -0.1,
#    'n_stags': 1},
#   'action_selector': 'multinomial',
#   'mixing_embed_dim': 32,
#   't_max': 1510000,
#   'load_step': 0,
#   'use_cuda': True,
#   'batch_size_run': 8,
#   'critic_lr': 0.0005,
#   'critic_train_reps': 1,
#   'critic_q_fn': 'coma',
#   'epsilon_finish': 0.01,
#   'epsilon_anneal_time': 100000,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'rnn_hidden_dim': 64,
#   'q_nstep': 0,
#   'obs_last_action': True,
#   'name': 'exp_marilena_coma_sh_1',
#   'epsilon_start': 0.5,
#   'obs_agent_id': True,
#   'mac': 'basic_mac',
#   'test_greedy': True,
#   'local_results_path': 'results',
#   'test_nepisode': 20,
#   'checkpoint_path': '',
#   'gamma': 0.99,
#   'env': 'stag_hunt',
#   'evaluate': False,
#   'critic_fact': None,
#   'seed': 722132159,
#   'repeat_id': 1,
#   'no-mongo': False,
#   'use_tensorboard': True,
#   'label': 'exp_marilena_coma_sh_1',
#   'grad_norm_clip': 10,
#   'mask_before_softmax': False,
#   'test_interval': 2000,
#   'buffer_size': 8,
#   'db_name': 'pymarl',
#   'save_model_interval': 2000000,
#   'learner_log_interval': 2000,
#   'agent': 'rnn',
#   'runner_log_interval': 2000,
#   'target_update_interval': 200,
#   'log_interval': 2000,
#   'td_lambda': 0.8,
#   'runner': 'parallel',
#   'batch_size': 8,
#   'buffer_cpu_only': True,
#   'agent_output_type': 'pi_logits'},
#  {'db_name': 'pymarl',
#   'name': 'exp_marilena_coma_sh_2',
#   'save_replay': False,
#   'repeat_id': 1,
#   'epsilon_anneal_time': 100000,
#   'test_nepisode': 20,
#   'save_model_interval': 2000000,
#   'action_selector': 'multinomial',
#   'evaluate': False,
#   'seed': 352253311,
#   'load_step': 0,
#   'test_greedy': True,
#   'q_nstep': 0,
#   'epsilon_finish': 0.01,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'rnn_hidden_dim': 64,
#   'learner': 'coma_learner',
#   'buffer_cpu_only': True,
#   'label': 'exp_marilena_coma_sh_2',
#   'local_results_path': 'results',
#   'save_model': False,
#   'env': 'stag_hunt',
#   'obs_last_action': True,
#   'optim_alpha': 0.99,
#   'obs_agent_id': True,
#   'td_lambda': 0.8,
#   'agent_output_type': 'pi_logits',
#   'target_update_interval': 200,
#   'mixer_lr': 0.0005,
#   'critic_baseline_fn': 'coma',
#   'batch_size': 8,
#   'critic_train_reps': 1,
#   't_max': 1510000,
#   'mask_before_softmax': False,
#   'no-mongo': False,
#   'checkpoint_path': '',
#   'critic_fact': None,
#   'gamma': 0.99,
#   'test_interval': 2000,
#   'runner_log_interval': 2000,
#   'mac': 'basic_mac',
#   'critic_lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'log_interval': 2000,
#   'optim_eps': 1e-05,
#   'mixing_embed_dim': 32,
#   'agent': 'rnn',
#   'lr': 0.0005,
#   'buffer_size': 8,
#   'env_args': {'reward_collision': 0.0,
#    'capture_conditions': [0, 1],
#    'n_agents': 4,
#    'n_hare': 1,
#    'intersection_global_view': False,
#    'state_last_action': False,
#    'observe_ids': False,
#    'agent_obs': [2, 2],
#    'world_shape': [6, 6],
#    'capture_terminal': True,
#    'reward_hare': 5,
#    'reward_time': -0.1,
#    'truncate_episodes': True,
#    'p_stags_rest': 0.0,
#    'n_stags': 1,
#    'reward_stag': 10,
#    'observe_walls': False,
#    'mountain_slope': 0.0,
#    'observe_one_hot': False,
#    'toroidal': False,
#    'print_caught_prey': False,
#    'p_hare_rest': 0.0,
#    'episode_limit': 100,
#    'intersection_unknown': False},
#   'runner': 'parallel',
#   'batch_size_run': 8,
#   'critic_q_fn': 'coma',
#   'grad_norm_clip': 10,
#   'learner_log_interval': 2000,
#   'use_cuda': True,
#   'epsilon_start': 0.5,
#   'use_tensorboard': True},
#  {'local_results_path': 'results',
#   'agent': 'rnn',
#   'load_step': 0,
#   'runner_log_interval': 2000,
#   'runner': 'parallel',
#   'no-mongo': False,
#   'critic_baseline_fn': 'coma',
#   'optim_eps': 1e-05,
#   'batch_size_run': 8,
#   'target_update_interval': 200,
#   'env_args': {'reward_hare': 5,
#    'n_hare': 1,
#    'p_hare_rest': 0.0,
#    'episode_limit': 100,
#    'mountain_slope': 0.0,
#    'reward_stag': 10,
#    'intersection_unknown': False,
#    'state_last_action': False,
#    'world_shape': [6, 6],
#    'capture_conditions': [0, 1],
#    'print_caught_prey': False,
#    'observe_ids': False,
#    'observe_one_hot': False,
#    'observe_walls': False,
#    'reward_time': -0.1,
#    'reward_collision': 0.0,
#    'n_stags': 1,
#    'n_agents': 4,
#    'toroidal': False,
#    'capture_terminal': True,
#    'agent_obs': [2, 2],
#    'intersection_global_view': False,
#    'p_stags_rest': 0.0,
#    'truncate_episodes': True},
#   'checkpoint_path': '',
#   'use_cuda': True,
#   'q_nstep': 0,
#   'buffer_size': 8,
#   'epsilon_anneal_time': 100000,
#   'learner': 'coma_learner',
#   'critic_lr': 0.0005,
#   'obs_last_action': True,
#   'rnn_hidden_dim': 64,
#   'batch_size': 8,
#   'critic_train_reps': 1,
#   'learner_log_interval': 2000,
#   'gamma': 0.99,
#   'epsilon_finish': 0.01,
#   'epsilon_start': 0.5,
#   'save_replay': False,
#   'grad_norm_clip': 10,
#   'repeat_id': 1,
#   'env': 'stag_hunt',
#   'name': 'exp_marilena_coma_sh_3',
#   'log_interval': 2000,
#   'db_name': 'pymarl',
#   'use_tensorboard': True,
#   'test_nepisode': 20,
#   'save_model_interval': 2000000,
#   'lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'critic_fact': None,
#   'mixing_embed_dim': 32,
#   'mixer_lr': 0.0005,
#   'optim_alpha': 0.99,
#   'buffer_cpu_only': True,
#   'test_interval': 2000,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'label': 'exp_marilena_coma_sh_3',
#   'agent_output_type': 'pi_logits',
#   'seed': 551332972,
#   'obs_agent_id': True,
#   'save_model': False,
#   'critic_q_fn': 'coma',
#   'mask_before_softmax': False,
#   'test_greedy': True,
#   'evaluate': False,
#   'td_lambda': 0.8,
#   'action_selector': 'multinomial',
#   't_max': 1510000,
#   'mac': 'basic_mac'},
#  {'checkpoint_path': '',
#   'evaluate': False,
#   'db_name': 'pymarl',
#   'agent': 'rnn',
#   'rnn_hidden_dim': 64,
#   'lr': 0.0005,
#   'env': 'stag_hunt',
#   'agent_output_type': 'pi_logits',
#   'grad_norm_clip': 10,
#   'critic_baseline_fn': 'coma',
#   'log_interval': 2000,
#   'epsilon_anneal_time': 100000,
#   'buffer_cpu_only': True,
#   'save_model': False,
#   'test_interval': 2000,
#   'runner': 'parallel',
#   'mac': 'basic_mac',
#   'q_nstep': 0,
#   'obs_last_action': True,
#   'mixer_lr': 0.0005,
#   'epsilon_start': 0.5,
#   'use_cuda': True,
#   'local_results_path': 'results',
#   'no-mongo': False,
#   'critic_fact': None,
#   'save_replay': False,
#   'mask_before_softmax': False,
#   'label': 'exp_marilena_coma_sh_4',
#   'optim_eps': 1e-05,
#   'action_selector': 'multinomial',
#   'obs_agent_id': True,
#   'test_nepisode': 20,
#   'use_tensorboard': True,
#   'critic_lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'learner_log_interval': 2000,
#   'seed': 51235237,
#   'test_greedy': True,
#   'env_args': {'p_hare_rest': 0.0,
#    'state_last_action': False,
#    'capture_terminal': True,
#    'print_caught_prey': False,
#    'reward_time': -0.1,
#    'intersection_global_view': False,
#    'observe_one_hot': False,
#    'n_hare': 1,
#    'truncate_episodes': True,
#    'observe_ids': False,
#    'agent_obs': [2, 2],
#    'intersection_unknown': False,
#    'capture_conditions': [0, 1],
#    'reward_hare': 5,
#    'n_agents': 4,
#    'episode_limit': 100,
#    'toroidal': False,
#    'observe_walls': False,
#    'reward_stag': 10,
#    'reward_collision': 0.0,
#    'p_stags_rest': 0.0,
#    'mountain_slope': 0.0,
#    'world_shape': [6, 6],
#    'n_stags': 1},
#   'learner': 'coma_learner',
#   'mixing_embed_dim': 32,
#   'gamma': 0.99,
#   'repeat_id': 1,
#   'critic_train_reps': 1,
#   'optim_alpha': 0.99,
#   'epsilon_finish': 0.01,
#   'buffer_size': 8,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'target_update_interval': 200,
#   'td_lambda': 0.8,
#   'name': 'exp_marilena_coma_sh_4',
#   'load_step': 0,
#   't_max': 1510000,
#   'batch_size': 8,
#   'batch_size_run': 8,
#   'critic_q_fn': 'coma',
#   'save_model_interval': 2000000,
#   'runner_log_interval': 2000},
#  {'checkpoint_path': '',
#   'critic_train_reps': 1,
#   'learner': 'coma_learner',
#   'mask_before_softmax': False,
#   'use_tensorboard': True,
#   'no-mongo': False,
#   'save_model_interval': 2000000,
#   'epsilon_anneal_time': 100000,
#   't_max': 1510000,
#   'mixer_lr': 0.0005,
#   'env_args': {'intersection_global_view': False,
#    'agent_obs': [2, 2],
#    'observe_one_hot': False,
#    'print_caught_prey': False,
#    'observe_walls': False,
#    'world_shape': [6, 6],
#    'toroidal': False,
#    'reward_time': -0.1,
#    'reward_hare': 5,
#    'mountain_slope': 0.0,
#    'reward_collision': 0.0,
#    'p_stags_rest': 0.0,
#    'p_hare_rest': 0.0,
#    'observe_ids': False,
#    'episode_limit': 100,
#    'truncate_episodes': True,
#    'intersection_unknown': False,
#    'n_agents': 4,
#    'n_stags': 1,
#    'capture_terminal': True,
#    'reward_stag': 10,
#    'state_last_action': False,
#    'n_hare': 1,
#    'capture_conditions': [0, 1]},
#   'name': 'exp_marilena_coma_sh_5',
#   'use_cuda': True,
#   'log_interval': 2000,
#   'test_greedy': True,
#   'td_lambda': 0.8,
#   'epsilon_start': 0.5,
#   'mixing_embed_dim': 32,
#   'runner_log_interval': 2000,
#   'critic_lr': 0.0005,
#   'optim_eps': 1e-05,
#   'local_results_path': 'results',
#   'gamma': 0.99,
#   'critic_baseline_fn': 'coma',
#   'mac': 'basic_mac',
#   'epsilon_finish': 0.01,
#   'runner': 'parallel',
#   'action_selector': 'multinomial',
#   'load_step': 0,
#   'optim_alpha': 0.99,
#   'obs_agent_id': True,
#   'q_nstep': 0,
#   'repeat_id': 1,
#   'label': 'exp_marilena_coma_sh_5',
#   'critic_train_mode': 'seq',
#   'db_name': 'pymarl',
#   'target_update_interval': 200,
#   'batch_size_run': 8,
#   'buffer_size': 8,
#   'rnn_hidden_dim': 64,
#   'env': 'stag_hunt',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'buffer_cpu_only': True,
#   'critic_q_fn': 'coma',
#   'lr': 0.0005,
#   'agent': 'rnn',
#   'seed': 799805908,
#   'critic_fact': None,
#   'evaluate': False,
#   'agent_output_type': 'pi_logits',
#   'learner_log_interval': 2000,
#   'obs_last_action': True,
#   'batch_size': 8,
#   'test_nepisode': 20,
#   'save_model': False,
#   'test_interval': 2000,
#   'save_replay': False,
#   'grad_norm_clip': 10},
#  {'name': 'exp_marilena_coma_sh_6',
#   'save_model': False,
#   'mixer_lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'mask_before_softmax': False,
#   'critic_q_fn': 'coma',
#   'epsilon_anneal_time': 100000,
#   'buffer_cpu_only': True,
#   'runner': 'parallel',
#   'checkpoint_path': '',
#   'critic_train_reps': 1,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'rnn_hidden_dim': 64,
#   'db_name': 'pymarl',
#   'test_interval': 2000,
#   'optim_alpha': 0.99,
#   'target_update_interval': 200,
#   'epsilon_start': 0.5,
#   'no-mongo': False,
#   'mixing_embed_dim': 32,
#   'repeat_id': 1,
#   'log_interval': 2000,
#   'q_nstep': 0,
#   'critic_fact': None,
#   'load_step': 0,
#   'mac': 'basic_mac',
#   'critic_lr': 0.0005,
#   'runner_log_interval': 2000,
#   'agent': 'rnn',
#   'save_replay': False,
#   'local_results_path': 'results',
#   'gamma': 0.99,
#   'buffer_size': 8,
#   'epsilon_finish': 0.01,
#   'grad_norm_clip': 10,
#   'use_tensorboard': True,
#   'batch_size': 8,
#   'action_selector': 'multinomial',
#   'obs_last_action': True,
#   'critic_baseline_fn': 'coma',
#   'use_cuda': True,
#   'learner_log_interval': 2000,
#   't_max': 1510000,
#   'batch_size_run': 8,
#   'learner': 'coma_learner',
#   'save_model_interval': 2000000,
#   'evaluate': False,
#   'env_args': {'reward_time': -0.1,
#    'state_last_action': False,
#    'episode_limit': 100,
#    'observe_ids': False,
#    'p_hare_rest': 0.0,
#    'truncate_episodes': True,
#    'world_shape': [6, 6],
#    'intersection_global_view': False,
#    'reward_hare': 5,
#    'intersection_unknown': False,
#    'n_agents': 4,
#    'n_stags': 1,
#    'observe_walls': False,
#    'toroidal': False,
#    'observe_one_hot': False,
#    'mountain_slope': 0.0,
#    'p_stags_rest': 0.0,
#    'capture_conditions': [0, 1],
#    'reward_collision': 0.0,
#    'capture_terminal': True,
#    'print_caught_prey': False,
#    'reward_stag': 10,
#    'n_hare': 1,
#    'agent_obs': [2, 2]},
#   'test_greedy': True,
#   'td_lambda': 0.8,
#   'seed': 82366292,
#   'test_nepisode': 20,
#   'agent_output_type': 'pi_logits',
#   'optim_eps': 1e-05,
#   'lr': 0.0005,
#   'obs_agent_id': True,
#   'env': 'stag_hunt',
#   'label': 'exp_marilena_coma_sh_6'},
#  {'critic_train_reps': 1,
#   'runner': 'parallel',
#   'critic_train_mode': 'seq',
#   'checkpoint_path': '',
#   'save_model_interval': 2000000,
#   'obs_last_action': True,
#   'load_step': 0,
#   'critic_q_fn': 'coma',
#   'optim_eps': 1e-05,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'epsilon_anneal_time': 100000,
#   'mask_before_softmax': False,
#   'seed': 592048055,
#   'batch_size': 8,
#   'test_greedy': True,
#   'target_update_interval': 200,
#   'repeat_id': 1,
#   'env_args': {'state_last_action': False,
#    'n_agents': 4,
#    'p_hare_rest': 0.0,
#    'observe_walls': False,
#    'print_caught_prey': False,
#    'capture_terminal': True,
#    'capture_conditions': [0, 1],
#    'reward_time': -0.1,
#    'observe_ids': False,
#    'intersection_global_view': False,
#    'n_hare': 1,
#    'episode_limit': 100,
#    'reward_hare': 5,
#    'reward_stag': 10,
#    'intersection_unknown': False,
#    'world_shape': [6, 6],
#    'mountain_slope': 0.0,
#    'p_stags_rest': 0.0,
#    'reward_collision': 0.0,
#    'observe_one_hot': False,
#    'truncate_episodes': True,
#    'n_stags': 1,
#    'toroidal': False,
#    'agent_obs': [2, 2]},
#   'mixing_embed_dim': 32,
#   'lr': 0.0005,
#   'grad_norm_clip': 10,
#   'use_cuda': True,
#   'action_selector': 'multinomial',
#   'save_replay': False,
#   'critic_lr': 0.0005,
#   'gamma': 0.99,
#   'critic_fact': None,
#   'buffer_cpu_only': True,
#   'test_interval': 2000,
#   'label': 'exp_marilena_coma_sh_11',
#   'local_results_path': 'results',
#   'learner': 'coma_learner',
#   'learner_log_interval': 2000,
#   'batch_size_run': 8,
#   'runner_log_interval': 2000,
#   'save_model': False,
#   'rnn_hidden_dim': 64,
#   'mac': 'basic_mac',
#   'optim_alpha': 0.99,
#   'q_nstep': 0,
#   'buffer_size': 8,
#   'agent': 'rnn',
#   'evaluate': False,
#   'epsilon_start': 0.5,
#   'critic_baseline_fn': 'coma',
#   'name': 'exp_marilena_coma_sh_11',
#   'use_tensorboard': True,
#   'obs_agent_id': True,
#   'db_name': 'pymarl',
#   'agent_output_type': 'pi_logits',
#   't_max': 1510000,
#   'log_interval': 2000,
#   'mixer_lr': 0.0005,
#   'env': 'stag_hunt',
#   'epsilon_finish': 0.01,
#   'no-mongo': False,
#   'test_nepisode': 20,
#   'td_lambda': 0.8},
#  {'obs_last_action': True,
#   'td_lambda': 0.8,
#   'mask_before_softmax': False,
#   'epsilon_start': 0.5,
#   'optim_alpha': 0.99,
#   'save_model': False,
#   'save_replay': False,
#   'mixer_lr': 0.0005,
#   'repeat_id': 1,
#   'lr': 0.0005,
#   'no-mongo': False,
#   'load_step': 0,
#   'epsilon_finish': 0.01,
#   'critic_train_mode': 'seq',
#   'target_update_interval': 200,
#   'gamma': 0.99,
#   'batch_size': 8,
#   'optim_eps': 1e-05,
#   'log_interval': 2000,
#   'label': 'exp_marilena_coma_sh_7',
#   'action_selector': 'multinomial',
#   'agent_output_type': 'pi_logits',
#   'runner': 'parallel',
#   'env': 'stag_hunt',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'mixing_embed_dim': 32,
#   'use_tensorboard': True,
#   'critic_baseline_fn': 'coma',
#   'use_cuda': True,
#   'critic_q_fn': 'coma',
#   'q_nstep': 0,
#   'buffer_cpu_only': True,
#   'learner': 'coma_learner',
#   'env_args': {'n_agents': 4,
#    'truncate_episodes': True,
#    'observe_walls': False,
#    'reward_stag': 10,
#    'reward_time': -0.1,
#    'reward_hare': 5,
#    'observe_one_hot': False,
#    'observe_ids': False,
#    'state_last_action': False,
#    'n_hare': 1,
#    'toroidal': False,
#    'p_hare_rest': 0.0,
#    'p_stags_rest': 0.0,
#    'reward_collision': 0.0,
#    'n_stags': 1,
#    'print_caught_prey': False,
#    'agent_obs': [2, 2],
#    'mountain_slope': 0.0,
#    'episode_limit': 100,
#    'capture_conditions': [0, 1],
#    'intersection_global_view': False,
#    'capture_terminal': True,
#    'world_shape': [6, 6],
#    'intersection_unknown': False},
#   'rnn_hidden_dim': 64,
#   'mac': 'basic_mac',
#   'obs_agent_id': True,
#   'critic_train_reps': 1,
#   'runner_log_interval': 2000,
#   'agent': 'rnn',
#   'learner_log_interval': 2000,
#   'db_name': 'pymarl',
#   'test_interval': 2000,
#   'test_greedy': True,
#   'name': 'exp_marilena_coma_sh_7',
#   'buffer_size': 8,
#   'local_results_path': 'results',
#   'critic_lr': 0.0005,
#   'evaluate': False,
#   'epsilon_anneal_time': 100000,
#   'checkpoint_path': '',
#   'seed': 129880961,
#   'grad_norm_clip': 10,
#   't_max': 1510000,
#   'critic_fact': None,
#   'save_model_interval': 2000000,
#   'batch_size_run': 8,
#   'test_nepisode': 20},
#  {'test_nepisode': 20,
#   'mixer_lr': 0.0005,
#   'critic_train_reps': 1,
#   't_max': 1510000,
#   'learner': 'coma_learner',
#   'agent': 'rnn',
#   'runner_log_interval': 2000,
#   'repeat_id': 1,
#   'critic_baseline_fn': 'coma',
#   'agent_output_type': 'pi_logits',
#   'learner_log_interval': 2000,
#   'mixing_embed_dim': 32,
#   'evaluate': False,
#   'seed': 876566950,
#   'checkpoint_path': '',
#   'optim_alpha': 0.99,
#   'name': 'exp_marilena_coma_sh_9',
#   'save_model_interval': 2000000,
#   'obs_agent_id': True,
#   'optim_eps': 1e-05,
#   'buffer_cpu_only': True,
#   'action_selector': 'multinomial',
#   'grad_norm_clip': 10,
#   'save_model': False,
#   'test_greedy': True,
#   'td_lambda': 0.8,
#   'no-mongo': False,
#   'use_tensorboard': True,
#   'env': 'stag_hunt',
#   'q_nstep': 0,
#   'env_args': {'world_shape': [6, 6],
#    'state_last_action': False,
#    'reward_collision': 0.0,
#    'truncate_episodes': True,
#    'observe_one_hot': False,
#    'intersection_global_view': False,
#    'p_hare_rest': 0.0,
#    'agent_obs': [2, 2],
#    'n_agents': 4,
#    'observe_ids': False,
#    'print_caught_prey': False,
#    'intersection_unknown': False,
#    'observe_walls': False,
#    'episode_limit': 100,
#    'n_stags': 1,
#    'capture_conditions': [0, 1],
#    'n_hare': 1,
#    'reward_time': -0.1,
#    'reward_hare': 5,
#    'capture_terminal': True,
#    'reward_stag': 10,
#    'toroidal': False,
#    'p_stags_rest': 0.0,
#    'mountain_slope': 0.0},
#   'test_interval': 2000,
#   'lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'batch_size_run': 8,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'load_step': 0,
#   'db_name': 'pymarl',
#   'rnn_hidden_dim': 64,
#   'critic_fact': None,
#   'buffer_size': 8,
#   'log_interval': 2000,
#   'mask_before_softmax': False,
#   'local_results_path': 'results',
#   'batch_size': 8,
#   'target_update_interval': 200,
#   'critic_lr': 0.0005,
#   'critic_q_fn': 'coma',
#   'gamma': 0.99,
#   'runner': 'parallel',
#   'use_cuda': True,
#   'save_replay': False,
#   'mac': 'basic_mac',
#   'epsilon_start': 0.5,
#   'obs_last_action': True,
#   'epsilon_finish': 0.01,
#   'label': 'exp_marilena_coma_sh_9',
#   'epsilon_anneal_time': 100000},
#  {'agent_output_type': 'pi_logits',
#   'log_interval': 2000,
#   'evaluate': False,
#   'critic_lr': 0.0005,
#   'env_args': {'n_stags': 1,
#    'p_hare_rest': 0.0,
#    'toroidal': False,
#    'state_last_action': False,
#    'reward_stag': 10,
#    'print_caught_prey': False,
#    'observe_one_hot': False,
#    'reward_time': -0.1,
#    'n_agents': 4,
#    'intersection_unknown': False,
#    'reward_hare': 5,
#    'truncate_episodes': True,
#    'p_stags_rest': 0.0,
#    'mountain_slope': 0.0,
#    'agent_obs': [2, 2],
#    'episode_limit': 100,
#    'observe_ids': False,
#    'world_shape': [6, 6],
#    'capture_terminal': True,
#    'n_hare': 1,
#    'capture_conditions': [0, 1],
#    'intersection_global_view': False,
#    'observe_walls': False,
#    'reward_collision': 0.0},
#   'rnn_hidden_dim': 64,
#   'test_greedy': True,
#   'buffer_cpu_only': True,
#   'q_nstep': 0,
#   'buffer_size': 8,
#   'learner_log_interval': 2000,
#   'mask_before_softmax': False,
#   'critic_baseline_fn': 'coma',
#   'action_selector': 'multinomial',
#   'critic_fact': None,
#   'mac': 'basic_mac',
#   'runner': 'parallel',
#   'mixer_lr': 0.0005,
#   'learner': 'coma_learner',
#   'save_replay': False,
#   'optim_eps': 1e-05,
#   'seed': 67085898,
#   'batch_size': 8,
#   'local_results_path': 'results',
#   'save_model': False,
#   'mixing_embed_dim': 32,
#   'agent': 'rnn',
#   'label': 'exp_marilena_coma_sh_12',
#   'gamma': 0.99,
#   'save_model_interval': 2000000,
#   'batch_size_run': 8,
#   'checkpoint_path': '',
#   'grad_norm_clip': 10,
#   'obs_agent_id': True,
#   'target_update_interval': 200,
#   'load_step': 0,
#   'name': 'exp_marilena_coma_sh_12',
#   'td_lambda': 0.8,
#   't_max': 1510000,
#   'critic_train_reps': 1,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'epsilon_anneal_time': 100000,
#   'critic_train_mode': 'seq',
#   'obs_last_action': True,
#   'env': 'stag_hunt',
#   'critic_q_fn': 'coma',
#   'runner_log_interval': 2000,
#   'test_interval': 2000,
#   'use_tensorboard': True,
#   'repeat_id': 1,
#   'test_nepisode': 20,
#   'use_cuda': True,
#   'db_name': 'pymarl',
#   'lr': 0.0005,
#   'optim_alpha': 0.99,
#   'no-mongo': False,
#   'epsilon_start': 0.5,
#   'epsilon_finish': 0.01},
#  {'gamma': 0.99,
#   'critic_train_mode': 'seq',
#   'batch_size': 8,
#   'epsilon_anneal_time': 100000,
#   'mask_before_softmax': False,
#   'agent_output_type': 'pi_logits',
#   'epsilon_start': 0.5,
#   'runner': 'parallel',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'use_cuda': True,
#   'grad_norm_clip': 10,
#   'no-mongo': False,
#   'use_tensorboard': True,
#   'db_name': 'pymarl',
#   'repeat_id': 1,
#   'rnn_hidden_dim': 64,
#   'critic_q_fn': 'coma',
#   'optim_alpha': 0.99,
#   'checkpoint_path': '',
#   'env_args': {'mountain_slope': 0.0,
#    'world_shape': [6, 6],
#    'agent_obs': [2, 2],
#    'reward_collision': 0.0,
#    'capture_conditions': [0, 1],
#    'reward_stag': 10,
#    'reward_hare': 5,
#    'observe_walls': False,
#    'state_last_action': False,
#    'observe_one_hot': False,
#    'truncate_episodes': True,
#    'n_agents': 4,
#    'episode_limit': 100,
#    'p_stags_rest': 0.0,
#    'capture_terminal': True,
#    'print_caught_prey': False,
#    'intersection_global_view': False,
#    'intersection_unknown': False,
#    'p_hare_rest': 0.0,
#    'n_hare': 1,
#    'toroidal': False,
#    'n_stags': 1,
#    'reward_time': -0.1,
#    'observe_ids': False},
#   'local_results_path': 'results',
#   'mac': 'basic_mac',
#   'env': 'stag_hunt',
#   'obs_agent_id': True,
#   'optim_eps': 1e-05,
#   'runner_log_interval': 2000,
#   'seed': 743812825,
#   'critic_lr': 0.0005,
#   'log_interval': 2000,
#   'test_nepisode': 20,
#   'test_interval': 2000,
#   'learner_log_interval': 2000,
#   'td_lambda': 0.8,
#   'load_step': 0,
#   'test_greedy': True,
#   'buffer_size': 8,
#   'mixing_embed_dim': 32,
#   'q_nstep': 0,
#   'critic_baseline_fn': 'coma',
#   'buffer_cpu_only': True,
#   'save_model': False,
#   'learner': 'coma_learner',
#   'agent': 'rnn',
#   'obs_last_action': True,
#   't_max': 1510000,
#   'lr': 0.0005,
#   'action_selector': 'multinomial',
#   'name': 'exp_marilena_coma_sh_8',
#   'mixer_lr': 0.0005,
#   'evaluate': False,
#   'save_replay': False,
#   'batch_size_run': 8,
#   'save_model_interval': 2000000,
#   'target_update_interval': 200,
#   'critic_fact': None,
#   'label': 'exp_marilena_coma_sh_8',
#   'epsilon_finish': 0.01,
#   'critic_train_reps': 1},
#  {'critic_fact': None,
#   'agent_output_type': 'pi_logits',
#   'env_args': {'capture_conditions': [0, 1],
#    'episode_limit': 100,
#    'n_stags': 1,
#    'reward_time': -0.1,
#    'intersection_unknown': False,
#    'p_stags_rest': 0.0,
#    'reward_hare': 5,
#    'n_hare': 1,
#    'capture_terminal': True,
#    'observe_walls': False,
#    'observe_ids': False,
#    'world_shape': [6, 6],
#    'intersection_global_view': False,
#    'toroidal': False,
#    'n_agents': 4,
#    'mountain_slope': 0.0,
#    'reward_stag': 10,
#    'agent_obs': [2, 2],
#    'state_last_action': False,
#    'truncate_episodes': True,
#    'observe_one_hot': False,
#    'print_caught_prey': False,
#    'reward_collision': 0.0,
#    'p_hare_rest': 0.0},
#   'obs_agent_id': True,
#   'learner': 'coma_learner',
#   'runner_log_interval': 2000,
#   'label': 'exp_marilena_coma_sh_10',
#   'test_nepisode': 20,
#   'optim_alpha': 0.99,
#   'agent': 'rnn',
#   'critic_train_reps': 1,
#   'save_model': False,
#   'rnn_hidden_dim': 64,
#   'buffer_cpu_only': True,
#   'q_nstep': 0,
#   'evaluate': False,
#   'mixing_embed_dim': 32,
#   'batch_size_run': 8,
#   'mixer_lr': 0.0005,
#   'test_greedy': True,
#   'load_step': 0,
#   'buffer_size': 8,
#   'epsilon_start': 0.5,
#   'test_interval': 2000,
#   'lr': 0.0005,
#   'td_lambda': 0.8,
#   'checkpoint_path': '',
#   'target_update_interval': 200,
#   'no-mongo': False,
#   't_max': 1510000,
#   'batch_size': 8,
#   'env': 'stag_hunt',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'critic_lr': 0.0005,
#   'critic_train_mode': 'seq',
#   'mac': 'basic_mac',
#   'runner': 'parallel',
#   'grad_norm_clip': 10,
#   'optim_eps': 1e-05,
#   'use_cuda': True,
#   'save_replay': False,
#   'seed': 70722612,
#   'save_model_interval': 2000000,
#   'local_results_path': 'results',
#   'mask_before_softmax': False,
#   'repeat_id': 1,
#   'obs_last_action': True,
#   'name': 'exp_marilena_coma_sh_10',
#   'learner_log_interval': 2000,
#   'db_name': 'pymarl',
#   'gamma': 0.99,
#   'action_selector': 'multinomial',
#   'use_tensorboard': True,
#   'critic_q_fn': 'coma',
#   'critic_baseline_fn': 'coma',
#   'log_interval': 2000,
#   'epsilon_finish': 0.01,
#   'epsilon_anneal_time': 100000},
#  {'critic_train_mode': 'seq',
#   'batch_size': 8,
#   'test_nepisode': 20,
#   'evaluate': False,
#   'action_selector': 'multinomial',
#   'target_update_interval': 200,
#   'save_model_interval': 2000000,
#   'learner_log_interval': 2000,
#   'label': 'exp_marilena_coma_sh_14',
#   'repeat_id': 1,
#   'env': 'stag_hunt',
#   'buffer_cpu_only': True,
#   'name': 'exp_marilena_coma_sh_14',
#   'no-mongo': False,
#   'log_interval': 2000,
#   'mixing_embed_dim': 32,
#   'gamma': 0.99,
#   't_max': 1510000,
#   'save_replay': False,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'seed': 416916159,
#   'td_lambda': 0.8,
#   'agent': 'rnn',
#   'test_interval': 2000,
#   'epsilon_finish': 0.01,
#   'critic_train_reps': 1,
#   'optim_eps': 1e-05,
#   'runner_log_interval': 2000,
#   'critic_baseline_fn': 'coma',
#   'lr': 0.0005,
#   'local_results_path': 'results',
#   'load_step': 0,
#   'critic_fact': None,
#   'obs_agent_id': True,
#   'epsilon_start': 0.5,
#   'grad_norm_clip': 10,
#   'use_tensorboard': True,
#   'critic_q_fn': 'coma',
#   'q_nstep': 0,
#   'optim_alpha': 0.99,
#   'mixer_lr': 0.0005,
#   'buffer_size': 8,
#   'mac': 'basic_mac',
#   'batch_size_run': 8,
#   'env_args': {'n_hare': 1,
#    'observe_ids': False,
#    'capture_conditions': [0, 1],
#    'n_agents': 4,
#    'world_shape': [6, 6],
#    'mountain_slope': 0.0,
#    'agent_obs': [2, 2],
#    'observe_one_hot': False,
#    'observe_walls': False,
#    'capture_terminal': True,
#    'print_caught_prey': False,
#    'reward_time': -0.1,
#    'reward_hare': 5,
#    'reward_stag': 10,
#    'intersection_unknown': False,
#    'state_last_action': False,
#    'p_stags_rest': 0.0,
#    'truncate_episodes': True,
#    'intersection_global_view': False,
#    'episode_limit': 100,
#    'toroidal': False,
#    'n_stags': 1,
#    'reward_collision': 0.0,
#    'p_hare_rest': 0.0},
#   'agent_output_type': 'pi_logits',
#   'rnn_hidden_dim': 64,
#   'mask_before_softmax': False,
#   'runner': 'parallel',
#   'obs_last_action': True,
#   'learner': 'coma_learner',
#   'save_model': False,
#   'db_name': 'pymarl',
#   'checkpoint_path': '',
#   'epsilon_anneal_time': 100000,
#   'test_greedy': True,
#   'critic_lr': 0.0005,
#   'use_cuda': True},
#  {'lr': 0.0005,
#   'obs_last_action': True,
#   'evaluate': False,
#   'optim_alpha': 0.99,
#   'action_selector': 'multinomial',
#   'epsilon_start': 0.5,
#   'buffer_size': 8,
#   'critic_q_fn': 'coma',
#   'label': 'exp_marilena_coma_sh_19',
#   'runner': 'parallel',
#   'grad_norm_clip': 10,
#   'checkpoint_path': '',
#   'critic_lr': 0.0005,
#   'use_cuda': True,
#   'target_update_interval': 200,
#   'agent_output_type': 'pi_logits',
#   'rnn_hidden_dim': 64,
#   'mixing_embed_dim': 32,
#   'epsilon_anneal_time': 100000,
#   'load_step': 0,
#   'db_name': 'pymarl',
#   'batch_size': 8,
#   'gamma': 0.99,
#   'epsilon_finish': 0.01,
#   'q_nstep': 0,
#   'save_model': False,
#   'test_interval': 2000,
#   'learner': 'coma_learner',
#   'mixer_lr': 0.0005,
#   'seed': 457671272,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'learner_log_interval': 2000,
#   'repeat_id': 1,
#   'critic_fact': None,
#   'name': 'exp_marilena_coma_sh_19',
#   'obs_agent_id': True,
#   'buffer_cpu_only': True,
#   'mask_before_softmax': False,
#   'td_lambda': 0.8,
#   'batch_size_run': 8,
#   'test_nepisode': 20,
#   'agent': 'rnn',
#   'log_interval': 2000,
#   'save_replay': False,
#   'critic_train_mode': 'seq',
#   'env_args': {'capture_terminal': True,
#    'reward_time': -0.1,
#    'intersection_unknown': False,
#    'observe_walls': False,
#    'intersection_global_view': False,
#    'toroidal': False,
#    'reward_collision': 0.0,
#    'p_stags_rest': 0.0,
#    'agent_obs': [2, 2],
#    'truncate_episodes': True,
#    'n_stags': 1,
#    'p_hare_rest': 0.0,
#    'n_agents': 4,
#    'observe_ids': False,
#    'reward_hare': 5,
#    'capture_conditions': [0, 1],
#    'observe_one_hot': False,
#    'print_caught_prey': False,
#    'state_last_action': False,
#    'n_hare': 1,
#    'mountain_slope': 0.0,
#    'world_shape': [6, 6],
#    'episode_limit': 100,
#    'reward_stag': 10},
#   'critic_train_reps': 1,
#   'mac': 'basic_mac',
#   'critic_baseline_fn': 'coma',
#   'use_tensorboard': True,
#   'test_greedy': True,
#   'env': 'stag_hunt',
#   't_max': 1510000,
#   'local_results_path': 'results',
#   'no-mongo': False,
#   'save_model_interval': 2000000,
#   'runner_log_interval': 2000,
#   'optim_eps': 1e-05},
#  {'load_step': 0,
#   'obs_last_action': True,
#   'critic_lr': 0.0005,
#   'buffer_cpu_only': True,
#   'runner': 'parallel',
#   'local_results_path': 'results',
#   'epsilon_start': 0.5,
#   'test_nepisode': 20,
#   'epsilon_finish': 0.01,
#   'test_interval': 2000,
#   'critic_fact': None,
#   'runner_log_interval': 2000,
#   'log_interval': 2000,
#   'seed': 375836437,
#   'action_selector': 'multinomial',
#   'save_replay': False,
#   'test_greedy': True,
#   'mixer_lr': 0.0005,
#   'agent_output_type': 'pi_logits',
#   'epsilon_anneal_time': 100000,
#   'gamma': 0.99,
#   'repeat_id': 1,
#   'rnn_hidden_dim': 64,
#   'critic_baseline_fn': 'coma',
#   'use_tensorboard': True,
#   'mixing_embed_dim': 32,
#   'obs_agent_id': True,
#   'learner_log_interval': 2000,
#   'grad_norm_clip': 10,
#   'critic_train_mode': 'seq',
#   'label': 'exp_marilena_coma_sh_16',
#   'save_model_interval': 2000000,
#   'checkpoint_path': '',
#   'use_cuda': True,
#   'buffer_size': 8,
#   'critic_q_fn': 'coma',
#   'lr': 0.0005,
#   'batch_size': 8,
#   'target_update_interval': 200,
#   'q_nstep': 0,
#   'env_args': {'intersection_unknown': False,
#    'world_shape': [6, 6],
#    'observe_ids': False,
#    'print_caught_prey': False,
#    'reward_stag': 10,
#    'episode_limit': 100,
#    'mountain_slope': 0.0,
#    'observe_one_hot': False,
#    'truncate_episodes': True,
#    'agent_obs': [2, 2],
#    'p_stags_rest': 0.0,
#    'reward_hare': 5,
#    'n_agents': 4,
#    'reward_collision': 0.0,
#    'observe_walls': False,
#    'p_hare_rest': 0.0,
#    'reward_time': -0.1,
#    'capture_conditions': [0, 1],
#    'capture_terminal': True,
#    'n_stags': 1,
#    'intersection_global_view': False,
#    'state_last_action': False,
#    'n_hare': 1,
#    'toroidal': False},
#   'optim_eps': 1e-05,
#   'critic_train_reps': 1,
#   'no-mongo': False,
#   'db_name': 'pymarl',
#   't_max': 1510000,
#   'td_lambda': 0.8,
#   'save_model': False,
#   'optim_alpha': 0.99,
#   'batch_size_run': 8,
#   'env': 'stag_hunt',
#   'learner': 'coma_learner',
#   'mac': 'basic_mac',
#   'name': 'exp_marilena_coma_sh_16',
#   'mask_before_softmax': False,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'evaluate': False,
#   'agent': 'rnn'},
#  {'td_lambda': 0.8,
#   'no-mongo': False,
#   'rnn_hidden_dim': 64,
#   'batch_size_run': 8,
#   'critic_train_reps': 1,
#   'log_interval': 2000,
#   'grad_norm_clip': 10,
#   'test_interval': 2000,
#   'save_model': False,
#   'gamma': 0.99,
#   'runner_log_interval': 2000,
#   'use_tensorboard': True,
#   'db_name': 'pymarl',
#   'critic_train_mode': 'seq',
#   'agent_output_type': 'pi_logits',
#   'buffer_size': 8,
#   'batch_size': 8,
#   'test_greedy': True,
#   'save_model_interval': 2000000,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'epsilon_start': 0.5,
#   'q_nstep': 0,
#   'critic_fact': None,
#   'target_update_interval': 200,
#   'label': 'exp_marilena_coma_sh_18',
#   't_max': 1510000,
#   'obs_last_action': True,
#   'env_args': {'observe_walls': False,
#    'intersection_unknown': False,
#    'n_agents': 4,
#    'state_last_action': False,
#    'agent_obs': [2, 2],
#    'truncate_episodes': True,
#    'reward_collision': 0.0,
#    'observe_one_hot': False,
#    'capture_terminal': True,
#    'observe_ids': False,
#    'capture_conditions': [0, 1],
#    'reward_time': -0.1,
#    'reward_hare': 5,
#    'n_stags': 1,
#    'world_shape': [6, 6],
#    'episode_limit': 100,
#    'intersection_global_view': False,
#    'p_stags_rest': 0.0,
#    'toroidal': False,
#    'mountain_slope': 0.0,
#    'print_caught_prey': False,
#    'n_hare': 1,
#    'reward_stag': 10,
#    'p_hare_rest': 0.0},
#   'seed': 109700137,
#   'mixer_lr': 0.0005,
#   'action_selector': 'multinomial',
#   'mask_before_softmax': False,
#   'mac': 'basic_mac',
#   'use_cuda': True,
#   'agent': 'rnn',
#   'learner_log_interval': 2000,
#   'optim_eps': 1e-05,
#   'epsilon_finish': 0.01,
#   'lr': 0.0005,
#   'critic_baseline_fn': 'coma',
#   'env': 'stag_hunt',
#   'evaluate': False,
#   'critic_lr': 0.0005,
#   'runner': 'parallel',
#   'learner': 'coma_learner',
#   'optim_alpha': 0.99,
#   'epsilon_anneal_time': 100000,
#   'test_nepisode': 20,
#   'critic_q_fn': 'coma',
#   'checkpoint_path': '',
#   'load_step': 0,
#   'mixing_embed_dim': 32,
#   'repeat_id': 1,
#   'save_replay': False,
#   'buffer_cpu_only': True,
#   'obs_agent_id': True,
#   'local_results_path': 'results',
#   'name': 'exp_marilena_coma_sh_18'},
#  {'learner_log_interval': 2000,
#   'repeat_id': 1,
#   'env_args': {'reward_hare': 5,
#    'world_shape': [6, 6],
#    'observe_one_hot': False,
#    'reward_collision': 0.0,
#    'p_hare_rest': 0.0,
#    'state_last_action': False,
#    'truncate_episodes': True,
#    'capture_conditions': [0, 1],
#    'toroidal': False,
#    'reward_stag': 10,
#    'n_stags': 1,
#    'intersection_unknown': False,
#    'print_caught_prey': False,
#    'intersection_global_view': False,
#    'agent_obs': [2, 2],
#    'reward_time': -0.1,
#    'n_agents': 4,
#    'observe_walls': False,
#    'p_stags_rest': 0.0,
#    'n_hare': 1,
#    'mountain_slope': 0.0,
#    'observe_ids': False,
#    'episode_limit': 100,
#    'capture_terminal': True},
#   'target_update_interval': 200,
#   'gamma': 0.99,
#   'critic_q_fn': 'coma',
#   'test_interval': 2000,
#   'learner': 'coma_learner',
#   'lr': 0.0005,
#   'epsilon_start': 0.5,
#   'db_name': 'pymarl',
#   'critic_baseline_fn': 'coma',
#   'batch_size_run': 8,
#   'local_results_path': 'results',
#   'use_tensorboard': True,
#   'seed': 618392964,
#   'load_step': 0,
#   'log_interval': 2000,
#   'evaluate': False,
#   'epsilon_anneal_time': 100000,
#   'action_selector': 'multinomial',
#   'obs_last_action': True,
#   'optim_eps': 1e-05,
#   'agent_output_type': 'pi_logits',
#   'buffer_cpu_only': True,
#   'mixing_embed_dim': 32,
#   'no-mongo': False,
#   'mixer_lr': 0.0005,
#   'critic_train_reps': 1,
#   'critic_fact': None,
#   'name': 'exp_marilena_coma_sh_15',
#   'epsilon_finish': 0.01,
#   'env': 'stag_hunt',
#   'test_greedy': True,
#   'runner_log_interval': 2000,
#   't_max': 1510000,
#   'label': 'exp_marilena_coma_sh_15',
#   'rnn_hidden_dim': 64,
#   'td_lambda': 0.8,
#   'mask_before_softmax': False,
#   'batch_size': 8,
#   'critic_train_mode': 'seq',
#   'test_nepisode': 20,
#   'save_replay': False,
#   'use_cuda': True,
#   'mac': 'basic_mac',
#   'q_nstep': 0,
#   'optim_alpha': 0.99,
#   'save_model': False,
#   'obs_agent_id': True,
#   'runner': 'parallel',
#   'grad_norm_clip': 10,
#   'agent': 'rnn',
#   'buffer_size': 8,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'critic_lr': 0.0005,
#   'save_model_interval': 2000000,
#   'checkpoint_path': ''},
#  {'test_greedy': True,
#   'agent': 'rnn',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'optim_eps': 1e-05,
#   'local_results_path': 'results',
#   'env': 'stag_hunt',
#   'obs_agent_id': True,
#   'use_tensorboard': True,
#   'checkpoint_path': '',
#   'runner': 'parallel',
#   'agent_output_type': 'pi_logits',
#   'epsilon_finish': 0.01,
#   'mac': 'basic_mac',
#   'epsilon_anneal_time': 100000,
#   'buffer_cpu_only': True,
#   'rnn_hidden_dim': 64,
#   'critic_train_reps': 1,
#   'test_interval': 2000,
#   'save_model_interval': 2000000,
#   'log_interval': 2000,
#   'name': 'exp_marilena_coma_sh_21',
#   'obs_last_action': True,
#   'critic_q_fn': 'coma',
#   'load_step': 0,
#   'runner_log_interval': 2000,
#   't_max': 1510000,
#   'target_update_interval': 200,
#   'buffer_size': 8,
#   'label': 'exp_marilena_coma_sh_21',
#   'repeat_id': 1,
#   'env_args': {'n_hare': 1,
#    'state_last_action': False,
#    'intersection_global_view': False,
#    'episode_limit': 100,
#    'capture_conditions': [0, 1],
#    'capture_terminal': True,
#    'truncate_episodes': True,
#    'reward_stag': 10,
#    'mountain_slope': 0.0,
#    'observe_walls': False,
#    'p_hare_rest': 0.0,
#    'print_caught_prey': False,
#    'p_stags_rest': 0.0,
#    'agent_obs': [2, 2],
#    'world_shape': [6, 6],
#    'reward_hare': 5,
#    'intersection_unknown': False,
#    'n_agents': 4,
#    'reward_collision': 0.0,
#    'reward_time': -0.1,
#    'observe_one_hot': False,
#    'observe_ids': False,
#    'toroidal': False,
#    'n_stags': 1},
#   'optim_alpha': 0.99,
#   'mask_before_softmax': False,
#   'critic_baseline_fn': 'coma',
#   'critic_fact': None,
#   'batch_size_run': 8,
#   'batch_size': 8,
#   'q_nstep': 0,
#   'db_name': 'pymarl',
#   'evaluate': False,
#   'learner': 'coma_learner',
#   'grad_norm_clip': 10,
#   'lr': 0.0005,
#   'use_cuda': True,
#   'seed': 102714017,
#   'mixing_embed_dim': 32,
#   'critic_train_mode': 'seq',
#   'mixer_lr': 0.0005,
#   'epsilon_start': 0.5,
#   'critic_lr': 0.0005,
#   'save_replay': False,
#   'gamma': 0.99,
#   'save_model': False,
#   'action_selector': 'multinomial',
#   'test_nepisode': 20,
#   'learner_log_interval': 2000,
#   'td_lambda': 0.8,
#   'no-mongo': False},
#  {'repeat_id': 1,
#   'buffer_size': 8,
#   'env_args': {'observe_one_hot': False,
#    'agent_obs': [2, 2],
#    'intersection_global_view': False,
#    'n_stags': 1,
#    'world_shape': [6, 6],
#    'reward_time': -0.1,
#    'state_last_action': False,
#    'n_hare': 1,
#    'toroidal': False,
#    'truncate_episodes': True,
#    'print_caught_prey': False,
#    'reward_stag': 10,
#    'reward_hare': 5,
#    'episode_limit': 100,
#    'n_agents': 4,
#    'p_hare_rest': 0.0,
#    'reward_collision': 0.0,
#    'observe_ids': False,
#    'capture_conditions': [0, 1],
#    'p_stags_rest': 0.0,
#    'observe_walls': False,
#    'intersection_unknown': False,
#    'capture_terminal': True,
#    'mountain_slope': 0.0},
#   'critic_train_reps': 1,
#   'name': 'exp_marilena_coma_sh_20',
#   'no-mongo': False,
#   'evaluate': False,
#   'db_name': 'pymarl',
#   'buffer_cpu_only': True,
#   't_max': 1510000,
#   'local_results_path': 'results',
#   'rnn_hidden_dim': 64,
#   'critic_q_fn': 'coma',
#   'use_tensorboard': True,
#   'agent': 'rnn',
#   'lr': 0.0005,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'test_interval': 2000,
#   'test_greedy': True,
#   'epsilon_finish': 0.01,
#   'epsilon_start': 0.5,
#   'seed': 239122807,
#   'epsilon_anneal_time': 100000,
#   'agent_output_type': 'pi_logits',
#   'mac': 'basic_mac',
#   'learner': 'coma_learner',
#   'log_interval': 2000,
#   'gamma': 0.99,
#   'env': 'stag_hunt',
#   'critic_lr': 0.0005,
#   'grad_norm_clip': 10,
#   'critic_baseline_fn': 'coma',
#   'mixing_embed_dim': 32,
#   'checkpoint_path': '',
#   'save_model': False,
#   'obs_last_action': True,
#   'optim_alpha': 0.99,
#   'target_update_interval': 200,
#   'runner': 'parallel',
#   'critic_train_mode': 'seq',
#   'save_model_interval': 2000000,
#   'mask_before_softmax': False,
#   'action_selector': 'multinomial',
#   'q_nstep': 0,
#   'load_step': 0,
#   'learner_log_interval': 2000,
#   'obs_agent_id': True,
#   'test_nepisode': 20,
#   'batch_size_run': 8,
#   'optim_eps': 1e-05,
#   'label': 'exp_marilena_coma_sh_20',
#   'td_lambda': 0.8,
#   'runner_log_interval': 2000,
#   'mixer_lr': 0.0005,
#   'save_replay': False,
#   'batch_size': 8,
#   'use_cuda': True,
#   'critic_fact': None},
#  {'critic_lr': 0.0005,
#   'epsilon_finish': 0.01,
#   'db_name': 'pymarl',
#   'buffer_size': 8,
#   'load_step': 0,
#   'local_results_path': 'results',
#   'test_interval': 2000,
#   'test_greedy': True,
#   'mask_before_softmax': False,
#   'buffer_cpu_only': True,
#   'env_args': {'state_last_action': False,
#    'intersection_unknown': False,
#    'observe_one_hot': False,
#    'p_stags_rest': 0.0,
#    'reward_time': -0.1,
#    'capture_terminal': True,
#    'capture_conditions': [0, 1],
#    'n_hare': 1,
#    'observe_ids': False,
#    'toroidal': False,
#    'reward_hare': 5,
#    'agent_obs': [2, 2],
#    'mountain_slope': 0.0,
#    'p_hare_rest': 0.0,
#    'n_agents': 4,
#    'episode_limit': 100,
#    'world_shape': [6, 6],
#    'reward_collision': 0.0,
#    'intersection_global_view': False,
#    'n_stags': 1,
#    'reward_stag': 10,
#    'print_caught_prey': False,
#    'truncate_episodes': True,
#    'observe_walls': False},
#   'log_interval': 2000,
#   'label': 'exp_marilena_coma_vdn_sh_21',
#   'repeat_id': 1,
#   'grad_norm_clip': 10,
#   'runner': 'parallel',
#   'save_model_interval': 2000000,
#   'save_replay': False,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'critic_train_reps': 1,
#   'mixer_lr': 0.0005,
#   'agent': 'rnn',
#   'test_nepisode': 20,
#   'checkpoint_path': '',
#   'obs_last_action': True,
#   'use_cuda': True,
#   'no-mongo': False,
#   'td_lambda': 0.8,
#   'mac': 'basic_mac',
#   'learner_log_interval': 2000,
#   'q_nstep': 0,
#   'epsilon_start': 0.5,
#   'epsilon_anneal_time': 100000,
#   'runner_log_interval': 2000,
#   'critic_fact': 'vdn',
#   'mixing_embed_dim': 32,
#   'gamma': 0.99,
#   'batch_size_run': 8,
#   'env': 'stag_hunt',
#   'name': 'exp_marilena_coma_vdn_sh_21',
#   'evaluate': False,
#   'rnn_hidden_dim': 64,
#   'critic_train_mode': 'seq',
#   'use_tensorboard': True,
#   'action_selector': 'multinomial',
#   'optim_eps': 1e-05,
#   'lr': 0.0005,
#   'critic_baseline_fn': 'coma',
#   'optim_alpha': 0.99,
#   'agent_output_type': 'pi_logits',
#   'obs_agent_id': True,
#   'target_update_interval': 200,
#   'critic_q_fn': 'coma',
#   'save_model': False,
#   'batch_size': 8,
#   'seed': 664498310,
#   't_max': 1510000,
#   'learner': 'coma_learner'},
#  {'mask_before_softmax': False,
#   'target_update_interval': 200,
#   'load_step': 0,
#   'label': 'exp_marilena_coma_vdn_sh_16',
#   'buffer_cpu_only': True,
#   'save_model': False,
#   'name': 'exp_marilena_coma_vdn_sh_16',
#   'log_interval': 2000,
#   'gamma': 0.99,
#   'checkpoint_path': '',
#   'optim_eps': 1e-05,
#   'mac': 'basic_mac',
#   'critic_q_fn': 'coma',
#   'test_greedy': True,
#   'evaluate': False,
#   'save_replay': False,
#   'runner_log_interval': 2000,
#   'no-mongo': False,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'buffer_size': 8,
#   'db_name': 'pymarl',
#   'q_nstep': 0,
#   'grad_norm_clip': 10,
#   'env': 'stag_hunt',
#   'local_results_path': 'results',
#   'learner': 'coma_learner',
#   'rnn_hidden_dim': 64,
#   'test_interval': 2000,
#   'test_nepisode': 20,
#   'repeat_id': 1,
#   'critic_train_mode': 'seq',
#   'critic_fact': 'vdn',
#   'critic_lr': 0.0005,
#   'critic_baseline_fn': 'coma',
#   'epsilon_start': 0.5,
#   'save_model_interval': 2000000,
#   'epsilon_anneal_time': 100000,
#   'runner': 'parallel',
# ...
#   'optim_eps': 1e-05,
#   'evaluate': False,
#   'repeat_id': 1,
#   'mask_before_softmax': False,
#   'checkpoint_path': '',
#   'runner_log_interval': 20000,
#   'mac': 'basic_mac',
#   'learner_log_interval': 20000,
#   'batch_size_run': 8,
#   't_max': 2010000,
#   'use_cuda': True,
#   'critic_train_reps': 1,
#   'critic_lr': 0.0005,
#   'epsilon_finish': 0.01,
#   'agent': 'rnn',
#   'save_replay': False,
#   'epsilon_anneal_time': 100000,
#   'lr': 0.0005,
#   'obs_agent_id': True,
#   'load_step': 0,
#   'td_lambda': 0.8,
#   'critic_fact': 'vdn',
#   'critic_train_mode': 'seq',
#   'local_results_path': 'results',
#   'test_greedy': True,
#   'seed': 337130213,
#   'buffer_size': 8,
#   'db_name': 'pymarl',
#   'action_selector': 'multinomial',
#   'learner': 'actor_critic_learner',
#   'log_interval': 20000,
#   'buffer_cpu_only': True,
#   'use_tensorboard': True,
#   'env': 'sc2',
#   'save_model_interval': 2000000},
#  {'use_cuda': True,
#   'local_results_path': 'results',
#   'runner_log_interval': 20000,
#   'test_nepisode': 24,
#   'repeat_id': 1,
#   'agent_output_type': 'pi_logits',
#   'buffer_cpu_only': True,
#   'optim_eps': 1e-05,
#   'critic_q_fn': 'centralV',
#   'obs_agent_id': True,
#   'q_nstep': 1,
#   'mac': 'basic_mac',
#   'obs_last_action': True,
#   'mask_before_softmax': False,
#   'test_interval': 20000,
#   'load_step': 0,
#   'save_model': False,
#   'optim_alpha': 0.99,
#   'test_greedy': True,
#   'env_args': {'reward_scale_rate': 20,
#    'obs_own_health': True,
#    'obs_pathing_grid': False,
#    'reward_scale': True,
#    'game_version': '4.6.2',
#    'difficulty': '7',
#    'move_amount': 2,
#    'reward_defeat': 0,
#    'obs_terrain_height': False,
#    'replay_dir': '',
#    'obs_last_action': False,
#    'replay_prefix': '',
#    'reward_win': 200,
#    'reward_only_positive': True,
#    'state_last_action': False,
#    'reward_negative_scale': 0.5,
#    'continuing_episode': False,
#    'reward_death_value': 10,
#    'debug': False,
#    'reward_sparse': False,
#    'step_mul': 8,
#    'obs_instead_of_state': False,
#    'obs_all_health': True,
#    'map_name': '2s3z'},
#   'gamma': 0.99,
#   'agent': 'rnn',
#   'critic_train_mode': 'seq',
#   'lr': 0.0005,
#   'seed': 451956427,
#   'db_name': 'pymarl',
#   'save_replay': False,
#   'runner': 'parallel',
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_10',
#   'epsilon_start': 0.5,
#   'rnn_hidden_dim': 64,
#   'env': 'sc2',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'td_lambda': 0.8,
#   'learner_log_interval': 20000,
#   'batch_size_run': 8,
#   'action_selector': 'multinomial',
#   'learner': 'actor_critic_learner',
#   'batch_size': 8,
#   'critic_lr': 0.0005,
#   'evaluate': False,
#   'critic_fact': 'vdn',
#   'save_model_interval': 2000000,
#   'grad_norm_clip': 10,
#   'log_interval': 20000,
#   'critic_train_reps': 1,
#   'epsilon_anneal_time': 100000,
#   'epsilon_finish': 0.01,
#   'no-mongo': False,
#   'critic_baseline_fn': 'centralV',
#   'buffer_size': 8,
#   'checkpoint_path': '',
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_10',
#   'target_update_interval': 200,
#   't_max': 2010000,
#   'use_tensorboard': True},
#  {'seed': 904395857,
#   'optim_eps': 1e-05,
#   'buffer_size': 8,
#   'no-mongo': False,
#   'local_results_path': 'results',
#   'epsilon_anneal_time': 100000,
#   'runner': 'parallel',
#   'evaluate': False,
#   'save_model': False,
#   't_max': 2010000,
#   'load_step': 0,
#   'learner_log_interval': 20000,
#   'epsilon_start': 0.5,
#   'agent_output_type': 'pi_logits',
#   'db_name': 'pymarl',
#   'target_update_interval': 200,
#   'grad_norm_clip': 10,
#   'test_nepisode': 24,
#   'q_nstep': 1,
#   'action_selector': 'multinomial',
#   'critic_fact': 'vdn',
#   'mac': 'basic_mac',
#   'batch_size_run': 8,
#   'lr': 0.0005,
#   'gamma': 0.99,
#   'save_replay': False,
#   'critic_q_fn': 'centralV',
#   'buffer_cpu_only': True,
#   'env_args': {'reward_scale': True,
#    'reward_sparse': False,
#    'difficulty': '7',
#    'map_name': '2s3z',
#    'move_amount': 2,
#    'obs_all_health': True,
#    'reward_defeat': 0,
#    'debug': False,
#    'obs_own_health': True,
#    'game_version': '4.6.2',
#    'continuing_episode': False,
#    'replay_dir': '',
#    'obs_terrain_height': False,
#    'reward_win': 200,
#    'obs_last_action': False,
#    'reward_death_value': 10,
#    'reward_scale_rate': 20,
#    'reward_negative_scale': 0.5,
#    'replay_prefix': '',
#    'obs_instead_of_state': False,
#    'step_mul': 8,
#    'obs_pathing_grid': False,
#    'reward_only_positive': True,
#    'state_last_action': False},
#   'checkpoint_path': '',
#   'batch_size': 8,
#   'log_interval': 20000,
#   'env': 'sc2',
#   'critic_baseline_fn': 'centralV',
#   'use_tensorboard': True,
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_5',
#   'critic_lr': 0.0005,
#   'optim_alpha': 0.99,
#   'runner_log_interval': 20000,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'obs_last_action': True,
#   'repeat_id': 1,
#   'critic_train_mode': 'seq',
#   'td_lambda': 0.8,
#   'use_cuda': True,
#   'test_greedy': True,
#   'agent': 'rnn',
#   'learner': 'actor_critic_learner',
#   'obs_agent_id': True,
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_5',
#   'critic_train_reps': 1,
#   'save_model_interval': 2000000,
#   'rnn_hidden_dim': 64,
#   'test_interval': 20000,
#   'mask_before_softmax': False,
#   'epsilon_finish': 0.01},
#  {'buffer_cpu_only': True,
#   'batch_size': 8,
#   'save_replay': False,
#   'no-mongo': False,
#   'optim_alpha': 0.99,
#   'critic_train_reps': 1,
#   'buffer_size': 8,
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_9',
#   'action_selector': 'multinomial',
#   'gamma': 0.99,
#   'epsilon_finish': 0.01,
#   'repeat_id': 1,
#   'test_nepisode': 24,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'obs_last_action': True,
#   'learner': 'actor_critic_learner',
#   't_max': 2010000,
#   'checkpoint_path': '',
#   'mask_before_softmax': False,
#   'env': 'sc2',
#   'seed': 5297085,
#   'runner': 'parallel',
#   'epsilon_start': 0.5,
#   'load_step': 0,
#   'optim_eps': 1e-05,
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_9',
#   'runner_log_interval': 20000,
#   'env_args': {'game_version': '4.6.2',
#    'state_last_action': False,
#    'reward_scale_rate': 20,
#    'reward_death_value': 10,
#    'obs_all_health': True,
#    'move_amount': 2,
#    'continuing_episode': False,
#    'obs_instead_of_state': False,
#    'reward_win': 200,
#    'map_name': '2s3z',
#    'reward_only_positive': True,
#    'replay_dir': '',
#    'reward_scale': True,
#    'reward_defeat': 0,
#    'obs_terrain_height': False,
#    'reward_negative_scale': 0.5,
#    'obs_last_action': False,
#    'difficulty': '7',
#    'step_mul': 8,
#    'obs_own_health': True,
#    'debug': False,
#    'obs_pathing_grid': False,
#    'replay_prefix': '',
#    'reward_sparse': False},
#   'critic_fact': 'vdn',
#   'test_greedy': True,
#   'epsilon_anneal_time': 100000,
#   'db_name': 'pymarl',
#   'td_lambda': 0.8,
#   'agent_output_type': 'pi_logits',
#   'q_nstep': 1,
#   'lr': 0.0005,
#   'grad_norm_clip': 10,
#   'save_model': False,
#   'target_update_interval': 200,
#   'critic_q_fn': 'centralV',
#   'critic_baseline_fn': 'centralV',
#   'use_cuda': True,
#   'evaluate': False,
#   'critic_lr': 0.0005,
#   'save_model_interval': 2000000,
#   'local_results_path': 'results',
#   'log_interval': 20000,
#   'agent': 'rnn',
#   'batch_size_run': 8,
#   'test_interval': 20000,
#   'rnn_hidden_dim': 64,
#   'learner_log_interval': 20000,
#   'critic_train_mode': 'seq',
#   'use_tensorboard': True,
#   'mac': 'basic_mac',
#   'obs_agent_id': True},
#  {'local_results_path': 'results',
#   'buffer_size': 8,
#   'optim_alpha': 0.99,
#   'critic_baseline_fn': 'centralV',
#   'env_args': {'reward_sparse': False,
#    'obs_own_health': True,
#    'reward_defeat': 0,
#    'debug': False,
#    'reward_only_positive': True,
#    'difficulty': '7',
#    'obs_pathing_grid': False,
#    'reward_scale': True,
#    'move_amount': 2,
#    'map_name': '2s3z',
#    'reward_scale_rate': 20,
#    'reward_negative_scale': 0.5,
#    'continuing_episode': False,
#    'obs_last_action': False,
#    'replay_dir': '',
#    'state_last_action': False,
#    'game_version': '4.6.2',
#    'obs_terrain_height': False,
#    'obs_instead_of_state': False,
#    'replay_prefix': '',
#    'reward_win': 200,
#    'reward_death_value': 10,
#    'step_mul': 8,
#    'obs_all_health': True},
#   'runner_log_interval': 20000,
#   'batch_size': 8,
#   'learner': 'actor_critic_learner',
#   'db_name': 'pymarl',
#   'gamma': 0.99,
#   'use_tensorboard': True,
#   'env': 'sc2',
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'test_nepisode': 24,
#   'critic_train_reps': 1,
#   'critic_train_mode': 'seq',
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_13',
#   'log_interval': 20000,
#   'target_update_interval': 200,
#   'repeat_id': 1,
#   'no-mongo': False,
#   'use_cuda': True,
#   'critic_fact': 'vdn',
#   'lr': 0.0005,
#   'mac': 'basic_mac',
#   'agent_output_type': 'pi_logits',
#   'obs_last_action': True,
#   'batch_size_run': 8,
#   'seed': 643759082,
#   'mask_before_softmax': False,
#   'save_replay': False,
#   'epsilon_finish': 0.01,
#   'action_selector': 'multinomial',
#   'td_lambda': 0.8,
#   'load_step': 0,
#   'grad_norm_clip': 10,
#   'epsilon_start': 0.5,
#   'epsilon_anneal_time': 100000,
#   'learner_log_interval': 20000,
#   'checkpoint_path': '',
#   'save_model_interval': 2000000,
#   'evaluate': False,
#   'agent': 'rnn',
#   'save_model': False,
#   'rnn_hidden_dim': 64,
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_13',
#   'critic_q_fn': 'centralV',
#   'obs_agent_id': True,
#   'critic_lr': 0.0005,
#   'optim_eps': 1e-05,
#   't_max': 2010000,
#   'test_interval': 20000,
#   'runner': 'parallel',
#   'buffer_cpu_only': True,
#   'test_greedy': True,
#   'q_nstep': 1},
#  {'learner_log_interval': 20000,
#   'load_step': 0,
#   'mask_before_softmax': False,
#   'no-mongo': False,
#   'critic_q_fn': 'centralV',
#   'critic_train_mode': 'seq',
#   'evaluate': False,
#   'log_interval': 20000,
#   'critic_baseline_fn': 'centralV',
#   'optim_alpha': 0.99,
#   't_max': 2010000,
#   'lr': 0.0005,
#   'critic_train_reps': 1,
#   'batch_size_run': 8,
#   'mac': 'basic_mac',
#   'grad_norm_clip': 10,
#   'obs_last_action': True,
#   'epsilon_anneal_time': 100000,
#   'test_interval': 20000,
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_15',
#   'batch_size': 8,
#   'buffer_cpu_only': True,
#   'epsilon_start': 0.5,
#   'learner': 'actor_critic_learner',
#   'test_nepisode': 24,
#   'critic_fact': 'vdn',
#   'td_lambda': 0.8,
#   'action_selector': 'multinomial',
#   'q_nstep': 1,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'save_model': False,
#   'test_greedy': True,
#   'obs_agent_id': True,
#   'local_results_path': 'results',
#   'use_tensorboard': True,
#   'runner': 'parallel',
#   'gamma': 0.99,
#   'critic_lr': 0.0005,
#   'optim_eps': 1e-05,
#   'rnn_hidden_dim': 64,
#   'save_replay': False,
#   'epsilon_finish': 0.01,
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_15',
#   'agent': 'rnn',
#   'seed': 849543789,
#   'repeat_id': 1,
#   'env': 'sc2',
#   'buffer_size': 8,
#   'checkpoint_path': '',
#   'env_args': {'replay_prefix': '',
#    'reward_negative_scale': 0.5,
#    'difficulty': '7',
#    'obs_terrain_height': False,
#    'replay_dir': '',
#    'debug': False,
#    'reward_win': 200,
#    'reward_scale_rate': 20,
#    'obs_all_health': True,
#    'continuing_episode': False,
#    'game_version': '4.6.2',
#    'obs_last_action': False,
#    'reward_sparse': False,
#    'reward_scale': True,
#    'reward_defeat': 0,
#    'state_last_action': False,
#    'obs_instead_of_state': False,
#    'map_name': '2s3z',
#    'reward_only_positive': True,
#    'step_mul': 8,
#    'obs_pathing_grid': False,
#    'obs_own_health': True,
#    'move_amount': 2,
#    'reward_death_value': 10},
#   'db_name': 'pymarl',
#   'agent_output_type': 'pi_logits',
#   'runner_log_interval': 20000,
#   'save_model_interval': 2000000,
#   'target_update_interval': 200,
#   'use_cuda': True},
#  {'test_greedy': True,
#   'env': 'sc2',
#   'action_selector': 'multinomial',
#   'mac': 'basic_mac',
#   'save_replay': False,
#   'td_lambda': 0.8,
#   'use_tensorboard': True,
#   'runner_log_interval': 20000,
#   'target_update_interval': 200,
#   'q_nstep': 1,
#   'load_step': 0,
#   'critic_fact': 'vdn',
#   'obs_last_action': True,
#   'batch_size': 8,
#   'repeat_id': 1,
#   'epsilon_anneal_time': 100000,
#   'critic_train_mode': 'seq',
#   'obs_agent_id': True,
#   'log_interval': 20000,
#   'buffer_cpu_only': True,
#   'learner_log_interval': 20000,
#   'checkpoint_path': '',
#   'gamma': 0.99,
#   'critic_q_fn': 'centralV',
#   'lr': 0.0005,
#   'env_args': {'reward_defeat': 0,
#    'reward_scale_rate': 20,
#    'obs_own_health': True,
#    'map_name': '2s3z',
#    'difficulty': '7',
#    'obs_all_health': True,
#    'continuing_episode': False,
#    'obs_instead_of_state': False,
#    'reward_negative_scale': 0.5,
#    'move_amount': 2,
#    'obs_pathing_grid': False,
#    'debug': False,
#    'game_version': '4.6.2',
#    'obs_last_action': False,
#    'reward_death_value': 10,
#    'obs_terrain_height': False,
#    'reward_scale': True,
#    'reward_sparse': False,
#    'reward_only_positive': True,
#    'state_last_action': False,
#    'replay_dir': '',
#    'step_mul': 8,
#    'reward_win': 200,
#    'replay_prefix': ''},
#   'epsilon_start': 0.5,
#   'evaluate': False,
#   'rnn_hidden_dim': 64,
#   'epsilon_finish': 0.01,
#   'save_model': False,
#   'use_cuda': True,
#   'batch_size_run': 8,
#   'runner': 'parallel',
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_14',
#   'test_nepisode': 24,
#   'critic_train_reps': 1,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'db_name': 'pymarl',
#   'mask_before_softmax': False,
#   'optim_eps': 1e-05,
#   'critic_lr': 0.0005,
#   'save_model_interval': 2000000,
#   'buffer_size': 8,
#   'grad_norm_clip': 10,
#   'optim_alpha': 0.99,
#   'test_interval': 20000,
#   't_max': 2010000,
#   'agent': 'rnn',
#   'seed': 213081180,
#   'no-mongo': False,
#   'local_results_path': 'results',
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_14',
#   'learner': 'actor_critic_learner',
#   'critic_baseline_fn': 'centralV',
#   'agent_output_type': 'pi_logits'},
#  {'checkpoint_path': '',
#   'test_interval': 20000,
#   'critic_q_fn': 'centralV',
#   'buffer_cpu_only': True,
#   'epsilon_finish': 0.01,
#   'repeat_id': 1,
#   'save_model_interval': 2000000,
#   'q_nstep': 1,
#   'db_url': 'mongodb://pymarlOwner:EMC7Jp98c8rE7FxxN7g82DT5spGsVr9A@gandalf.cs.ox.ac.uk:27017/pymarl',
#   'local_results_path': 'results',
#   'no-mongo': False,
#   'epsilon_anneal_time': 100000,
#   'log_interval': 20000,
#   'learner_log_interval': 20000,
#   'gamma': 0.99,
#   'seed': 111767633,
#   'optim_eps': 1e-05,
#   'obs_agent_id': True,
#   'grad_norm_clip': 10,
#   'critic_fact': 'vdn',
#   'use_tensorboard': True,
#   'critic_lr': 0.0005,
#   'batch_size': 8,
#   'db_name': 'pymarl',
#   'save_replay': False,
#   'batch_size_run': 8,
#   'evaluate': False,
#   'mask_before_softmax': False,
#   'runner': 'parallel',
#   'runner_log_interval': 20000,
#   'target_update_interval': 200,
#   'learner': 'actor_critic_learner',
#   'critic_baseline_fn': 'centralV',
#   'agent': 'rnn',
#   'obs_last_action': True,
#   'use_cuda': True,
#   'td_lambda': 0.8,
#   'critic_train_reps': 1,
#   'save_model': False,
#   'action_selector': 'multinomial',
#   'env_args': {'map_name': '2s3z',
#    'step_mul': 8,
#    'replay_dir': '',
#    'obs_all_health': True,
#    'debug': False,
#    'reward_scale_rate': 20,
#    'obs_instead_of_state': False,
#    'reward_death_value': 10,
#    'reward_negative_scale': 0.5,
#    'move_amount': 2,
#    'reward_sparse': False,
#    'game_version': '4.6.2',
#    'obs_last_action': False,
#    'reward_defeat': 0,
#    'difficulty': '7',
#    'reward_win': 200,
#    'replay_prefix': '',
#    'reward_scale': True,
#    'obs_pathing_grid': False,
#    'continuing_episode': False,
#    'obs_terrain_height': False,
#    'reward_only_positive': True,
#    'obs_own_health': True,
#    'state_last_action': False},
#   'agent_output_type': 'pi_logits',
#   'test_nepisode': 24,
#   'label': 'exp_marilena_centralV_vdn_sc_2s3z_12',
#   'optim_alpha': 0.99,
#   'buffer_size': 8,
#   't_max': 2010000,
#   'mac': 'basic_mac',
#   'name': 'exp_marilena_centralV_vdn_sc_2s3z_12',
#   'load_step': 0,
#   'test_greedy': True,
#   'critic_train_mode': 'seq',
#   'env': 'sc2',
#   'lr': 0.0005,
#   'rnn_hidden_dim': 64,
#   'epsilon_start': 0.5}]

# %%
def get_config_for_db(game, exp, special_config):
    base_config = {
        "config.name": {'$regex': '^exp_marilena'}
    }
    return base_config

# %%
def plot_means(game, type_of_data, experiments, percentile=False, conf_inter=False, \
               figure_file_name=None, special_config=None, labels):
    for exp in experiments:
        assert exp in possible_experiments
    
    step_count = game_step_counts[game]
    timesteps = np.linspace(0, step_count, DATAPOINTS_COUNT)
    
    fig, axes = plt.subplots(1, 1, figsize=(20, 10))
    fig.suptitle(game_titles[game], fontsize=20)
    
    assert len(labels) == len(experiments)
    
    if special_config is not None:
        assert len(experiments) == len(special_config)
    
    for idx, exp in enumerate(experiments):
        color = exp_color_map[exp]
        
        config_db = get_config_for_db(game, exp, special_config[idx])
        
        exp_ids = get_exp_ids_from_db(config_db)
        
        if len(exp_ids) == 0:
            print("No experiments with " + exp + game)
            continue
            
        label = labels[idx].format(len(exp_ids))
        print("Plotting experiments with " + exp + game)
        
        means, curr_timesteps = get_means_exp_data(game, exp_ids, type_of_data)
        
        if conf_inter:
            sems, curr_timesteps = get_sems_exp_data(game, exp_ids, type_of_data)
            confidence_intervals_low, confidence_intervals_up = get_confidence_intervals(means, sems)
            axes.fill_between(timesteps, confidence_intervals_low, confidence_intervals_up, facecolor=color, alpha=0.3)
        
        if percentile:
            p25, p75 = get_percentile_threshold_exp_data(game, exp_ids, type_of_data)
            axes.fill_between(timesteps, p25, p75, facecolor=color, alpha=0.3)
        
        axes.plot(timesteps, means, color=color, label=label)
        axes.set_ylabel(axes_labels[type_of_data], fontsize=14)
    
        axes.legend(loc="upper left")
        if figure_file_name is not None:
            plt.savefig(figure_file_name)
